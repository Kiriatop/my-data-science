# %% [markdown]
# # **Crypto money analytics prediction**

# %% [markdown]
# ### **installing required libraries**

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time
# !pip install selenium
from selenium import webdriver  # pip install selenium
from selenium.webdriver.chrome.service import Service
# !pip install webdriver_manager
from webdriver_manager.chrome import ChromeDriverManager  # pip install webdriver-manager
import re

# %%
# !pip install telebot
import telebot
import requests

# %% [markdown]
# ## Developing bot

# %%
bot = telebot.TeleBot('6508836008:AAG9LX9OL_r1SV7XKKcoFTHwMDe3sYjdTd8')


@bot.message_handler(commands = ['start'])
def func1(message):
    bot.send_message(message.chat.id, 'Hello! It`s new telegram crypto bot. to check does crypto got yout limit enter /does_price_get')
    
q1 = list()
q2 = list()   
q3 = list()
q4 = list()

@bot.message_handler(commands = ['do_price_get'])
def func11(message):
         msg = bot.send_message(message.chat.id, 'Enter price: ')
         bot.register_next_step_handler(msg, func111)

@bot.message_handler(commands = ['set_ml'])
def func111(message):
        a = message.text.lower()
        q4.append(a)
        msg = bot.send_message(message.chat.id, 'Enter more or less: ')
        bot.register_next_step_handler(msg, func3)
            
         
@bot.message_handler(commands = ['set_crypto'])
def func3(message):
    first = message.text.lower()
    q4.append(first)
    msg = bot.send_message(message.chat.id, 'Enter crypto: ')
    bot.register_next_step_handler(msg, func4)

@bot.message_handler(commands = ['is_got'])
def func4(message):
    for c in open('C://users/1/Downloads/records.txt','r'):
        bc = re.findall('[a-zA-Z]*', c)     
        for i in bc:  
            if i.lower() == message.text.lower():
                    while True:
                        #try:
                            crypto = str(i).lower()
                            URL = 'https://www.binance.com/ru-UA/price/' + str(crypto)
                            responce = requests.get(URL).text
                            soup = BeautifulSoup(responce, 'html.parser')
                            #bot.send_message(message.chat.id, 'loh')
                            for i in soup.find_all('div'):
                                if i.get('id') == '__APP':
                                    q = i.find_all('div')[0].find_all('div')[5].find_all('div')[43]
                                    q = str(q)[46:]
                                    q = q.replace(',', '')
                                    q = q.replace('</div>', '')
                                    a = dt.now()
                                    #q1.append(q)
                                    #q2.append(a)
                                    if q4[1] == 'less' and float(q) <= float(q4[0]):                                
                                        bot.send_message(message.chat.id,'The price got your limit ')
                                        break
                                    if q4[1] == 'more' and float(q) >= float(q4[0]):                                
                                        bot.send_message(message.chat.id, 'The price got your limit')
                                        break
                                    
                               
                        #except:
                            #bot.send_message(message.chat.id, 'There is no crypto with this name')
                    
                            time.sleep(300)
                        
#@bot.message_handler(commands = ['open_interest_grow'])
#def func5(message):
    #asv = 0
    #aaq = []
    #while True:
        ##driver.get("https://www.coinglass.com/BitcoinOpenInterest")  # open page
            time.sleep(5)  # time to load webpage
            soup = BeautifulSoup(driver.page_source, 'html.parser')  
        #time.sleep(10)
        b = []
        w = 0
        aq = []
        aqq = 0
        for i in soup('tbody')[0].find_all('tr'):
            aq.append([])
            bc = i.find_all('td')
            for a in bc:
                aq[aqq].append(a)
            aqq = aqq + 1
        avv = 0
        for a in aq:
            try:
                i = str(a[3].find('div'))[30:]
                i = i.replace('</div>', '')
                i = i.replace('$', '')
                i = i.replace('B', '000000000')
                i = i.replace('M', '000000')
                i = i.replace('.', '')
                if i != 'hidden">\xa0':
                    aaq.append(list())
                    aaq[av].append(int(i))
            except:
                pass
            asv = asv + 1
    
        for c in aaq:
            avv = avv + 1
            #try:
            if aaq[avv + (asv-1)*10] > aaq[avv]:
                    bot.send_message(message.chat.id, 'Done')
                    break
            #except:
            #bot.send_message(message.chat.id, 'Done11')
    
bot.polling(none_stop = True)
print(0)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
# ...
